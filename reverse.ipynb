# %% [markdown]
# <a href="https://colab.research.google.com/github/wanderloop/WanderlustAI/blob/master/reverse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow
from cv2 import imread, IMREAD_COLOR, rectangle, circle, waitKey, destroyAllWindows
img = imread('/content/1.jpg',
             IMREAD_COLOR,)

# rectangle(img,
#           (894,458),
#           (982,706),
#           (0,0,255),
#            5,)

# 975.17032471,339.61942762
# 976.98126274,237.94703286
# 882.88791445,334.29773593

a=882
b=334
circle(img,
       (int(a),
        int(b)),
        10,
       (0,255,0), 
        -1,)

cv2_imshow(img)
waitKey(0)
destroyAllWindows()

# Left=892, Top=458, Right=982, Bottom=706
# Out:
# <PIL.Image.Image image mode=RGB size=1280x960 at 0x7FC1A10D72B0>
